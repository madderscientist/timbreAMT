# %% [markdown]
# # "音色分离转录"模型评估
# 转录和编码分支共享第一个残差块及之前的所有
#
# ## 生成转录结果并保存
# 经过process后每个文件夹里的文件只有后缀不同，且后缀为"npy" "wav" "mid"。wav采样率已经是22050Hz。

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import os
from timbre_sepatate_eval_utils import *
import sys
sys.path.append('..')

s_per_frame = 256 / 22050

# %% [markdown]
# ### 运行模型

# %%
model_folder_name = "dicephnet"
sys.path.append(f'../septimbre/ablation/DicephNet/')
model = torch.load(f"../septimbre/ablation/DicephNet/dicephnet_model.pth", weights_only=False)
model.eval()

# %%
# 得到所有2、3混合的运行结果
with torch.no_grad():
    amt_mix_dataset(model, 'BACH10_processed', 2, f"./{model_folder_name}")
    amt_mix_dataset(model, 'BACH10_processed', 3, f"./{model_folder_name}")
    amt_mix_dataset(model, 'BACH10_processed', 4, f"./{model_folder_name}")
    amt_urmp(model, f"./{model_folder_name}", 2)
    amt_urmp(model, f"./{model_folder_name}", 3)

# %% [markdown]
# ### 寻找最好阈值

# %%
# 为了方便粘贴到excel
output_results = {}
frame_level_cluster = True
def print_results(results):
    result_arr = []
    for key, detail in results.items():
        result_arr.extend([str(v) for k, v in detail.items()])
    print("|".join(result_arr))

# %%
# BACH10的2合奏
npyfolder = f"{model_folder_name}/BACH10_eval"
npys = [os.path.join(npyfolder, f) for f in os.listdir(npyfolder) if ifNmix(f, 2)]
best_thre, max_acc, max_p, max_r, max_f1 = find_best_threshold(npys, (0.1, 0.8), step_num=6, generation=5, log=True)
print("note level evaluation at best threshold:")
best_onset_thre, note_p, note_r, note_f, note_overlap = find_best_onset_threshold(npys, best_thre, (0.3, 0.9), step_num=6, generation=5, log=True)
(sep_P, sep_R, sep_F, sep_Overlap), (f_sep_P, f_sep_R, f_sep_F, f_sep_Overlap) = evaluate_sep_note_dataset(npyfolder, frame_thresh=best_thre, onset_thresh=best_onset_thre, mix=2, log=True, frame_level=frame_level_cluster)
output_results["BACH10_2mix"] = {
    "frame_thre": best_thre,
    "frame_acc": max_acc,
    "frame_p": max_p,
    "frame_r": max_r,
    "frame_f1": max_f1,
    "onset_thre": best_onset_thre,
    "note_p": note_p,
    "note_r": note_r,
    "note_f": note_f,
    "note_overlap": note_overlap,
    "sep_p": sep_P,
    "sep_r": sep_R,
    "sep_f": sep_F,
    "sep_overlap": sep_Overlap,
    "frame_sep_p": f_sep_P,
    "frame_sep_r": f_sep_R,
    "frame_sep_f": f_sep_F,
    "frame_sep_overlap": f_sep_Overlap
}

# %%
# BACH10的3合奏
npyfolder = f"{model_folder_name}/BACH10_eval"
npys = [os.path.join(npyfolder, f) for f in os.listdir(npyfolder) if ifNmix(f, 3)]
best_thre, max_acc, max_p, max_r, max_f1 = find_best_threshold(npys, (0.1, 0.6), step_num=6, generation=5, log=True)
print("note level evaluation at best threshold:")
best_onset_thre, note_p, note_r, note_f, note_overlap = find_best_onset_threshold(npys, best_thre, (0.2, 0.8), step_num=6, generation=5, log=True)
(sep_P, sep_R, sep_F, sep_Overlap), (f_sep_P, f_sep_R, f_sep_F, f_sep_Overlap) = evaluate_sep_note_dataset(npyfolder, frame_thresh=best_thre, onset_thresh=best_onset_thre, mix=3, log=True, frame_level=frame_level_cluster)
output_results["BACH10_3mix"] = {
    "frame_thre": best_thre,
    "frame_acc": max_acc,
    "frame_p": max_p,
    "frame_r": max_r,
    "frame_f1": max_f1,
    "onset_thre": best_onset_thre,
    "note_p": note_p,
    "note_r": note_r,
    "note_f": note_f,
    "note_overlap": note_overlap,
    "sep_p": sep_P,
    "sep_r": sep_R,
    "sep_f": sep_F,
    "sep_overlap": sep_Overlap,
    "frame_sep_p": f_sep_P,
    "frame_sep_r": f_sep_R,
    "frame_sep_f": f_sep_F,
    "frame_sep_overlap": f_sep_Overlap
}

# %%
# BACH10的4合奏
npyfolder = f"{model_folder_name}/BACH10_eval"
npys = [os.path.join(npyfolder, f) for f in os.listdir(npyfolder) if ifNmix(f, 4)]
best_thre, max_acc, max_p, max_r, max_f1 = find_best_threshold(npys, (0.1, 0.6), step_num=6, generation=5, log=True)
print("note level evaluation at best threshold:")
best_onset_thre, note_p, note_r, note_f, note_overlap = find_best_onset_threshold(npys, best_thre, (0.2, 0.8), step_num=6, generation=5, log=True)
(sep_P, sep_R, sep_F, sep_Overlap), (f_sep_P, f_sep_R, f_sep_F, f_sep_Overlap) = evaluate_sep_note_dataset(npyfolder, frame_thresh=best_thre, onset_thresh=best_onset_thre, mix=4, log=True, frame_level=frame_level_cluster)
output_results["BACH10_4mix"] = {
    "frame_thre": best_thre,
    "frame_acc": max_acc,
    "frame_p": max_p,
    "frame_r": max_r,
    "frame_f1": max_f1,
    "onset_thre": best_onset_thre,
    "note_p": note_p,
    "note_r": note_r,
    "note_f": note_f,
    "note_overlap": note_overlap,
    "sep_p": sep_P,
    "sep_r": sep_R,
    "sep_f": sep_F,
    "sep_overlap": sep_Overlap,
    "frame_sep_p": f_sep_P,
    "frame_sep_r": f_sep_R,
    "frame_sep_f": f_sep_F,
    "frame_sep_overlap": f_sep_Overlap
}

# %%
# URMP的2合奏
npyfolder = f"{model_folder_name}/URMP_eval"
npys = [os.path.join(npyfolder, f) for f in os.listdir(npyfolder) if ifNmix(f, 2)]
best_thre, max_acc, max_p, max_r, max_f1 = find_best_threshold(npys, (0.1, 0.6), step_num=6, generation=5, log=True)
print("note level evaluation at best threshold:")
best_onset_thre, note_p, note_r, note_f, note_overlap = find_best_onset_threshold(npys, best_thre, (0.2, 0.6), step_num=6, generation=5, log=True)
(sep_P, sep_R, sep_F, sep_Overlap), (f_sep_P, f_sep_R, f_sep_F, f_sep_Overlap) = evaluate_sep_note_dataset(npyfolder, frame_thresh=best_thre, onset_thresh=best_onset_thre, mix=2, log=True, frame_level=frame_level_cluster)
output_results["URMP_2mix"] = {
    "frame_thre": best_thre,
    "frame_acc": max_acc,
    "frame_p": max_p,
    "frame_r": max_r,
    "frame_f1": max_f1,
    "onset_thre": best_onset_thre,
    "note_p": note_p,
    "note_r": note_r,
    "note_f": note_f,
    "note_overlap": note_overlap,
    "sep_p": sep_P,
    "sep_r": sep_R,
    "sep_f": sep_F,
    "sep_overlap": sep_Overlap,
    "frame_sep_p": f_sep_P,
    "frame_sep_r": f_sep_R,
    "frame_sep_f": f_sep_F,
    "frame_sep_overlap": f_sep_Overlap
}

# %%
# URMP的3合奏
npyfolder = f"{model_folder_name}/URMP_eval"
npys = [os.path.join(npyfolder, f) for f in os.listdir(npyfolder) if ifNmix(f, 3)]
best_thre, max_acc, max_p, max_r, max_f1 = find_best_threshold(npys, (0.1, 0.6), step_num=6, generation=5, log=True)
print("note level evaluation at best threshold:")
best_onset_thre, note_p, note_r, note_f, note_overlap = find_best_onset_threshold(npys, best_thre, (0.2, 0.6), step_num=6, generation=5, log=True)
(sep_P, sep_R, sep_F, sep_Overlap), (f_sep_P, f_sep_R, f_sep_F, f_sep_Overlap) = evaluate_sep_note_dataset(npyfolder, frame_thresh=best_thre, onset_thresh=best_onset_thre, mix=3, log=True, frame_level=frame_level_cluster)
output_results["URMP_3mix"] = {
    "frame_thre": best_thre,
    "frame_acc": max_acc,
    "frame_p": max_p,
    "frame_r": max_r,
    "frame_f1": max_f1,
    "onset_thre": best_onset_thre,
    "note_p": note_p,
    "note_r": note_r,
    "note_f": note_f,
    "note_overlap": note_overlap,
    "sep_p": sep_P,
    "sep_r": sep_R,
    "sep_f": sep_F,
    "sep_overlap": sep_Overlap,
    "frame_sep_p": f_sep_P,
    "frame_sep_r": f_sep_R,
    "frame_sep_f": f_sep_F,
    "frame_sep_overlap": f_sep_Overlap
}

# %%
print_results(output_results)

# %%
# 输出参数数量
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
print(count_parameters(model))

# %% [markdown]
# ## t-SNE可视化音色编码
# 并不好。只有2&4（clarinet & bassoon）分得开，其余都混在一起。

# %%
from sklearn.manifold import TSNE
import numpy as np
from matplotlib import pyplot as plt

tsne = TSNE(n_components=2)

def extrace_timbre_emb(npy_path):
    if not npy_path.endswith('.npz'):
        npy_path += '.npz'
    result = np.load(npy_path)
    emb = result['emb']  # (D, T, 128)
    midi = result['midi']  # (mix, T)
    emb_extracted = []
    for n in midi:
        p = np.where(n > 0.1)
        emb_one = emb[:, p[0], p[1]].T        # (n, 18)
        emb_extracted.append(emb_one)
    return emb_extracted

# %%
npy_path = "./septimbre/URMP_eval/01_Jupiter_vn_vc_1&2.npz"

emb_extracted = extrace_timbre_emb(npy_path)    # (mix, n, 18)
# 合并所有mix的数据
X_all = np.concatenate(emb_extracted, axis=0)
y_all = []
for idx, X_part in enumerate(emb_extracted):
    y_all.extend([idx] * len(X_part))
y_all = np.array(y_all)

X_tsne = tsne.fit_transform(X_all)
for idx in range(len(emb_extracted)):
    plt.scatter(
        X_tsne[y_all == idx, 0],
        X_tsne[y_all == idx, 1],
        label=f"mix {idx+1}",
        alpha=0.6
    )
plt.legend()
plt.title(f"t-SNE visualization for {npy_path}")
plt.show()
