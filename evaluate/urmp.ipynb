# %% [markdown]
# # 处理[URMP](https://labsites.rochester.edu/air/projects/URMP.html)数据集

# %%
import os
import subprocess
import shutil
import mido
import numpy as np
import sys
sys.path.append("..")
from utils.midiarray import midi_merge, annotation2midi, midi2numpy

dataset_folder = "../data/URMP/Dataset"
output_folder = "./URMP_processed"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 目标音频
fs = 22050
hop = 256
time_step = hop / fs

# 乐器标注
urmp_instruments = {
    "vn": 40,
    "va": 41,
    "vc": 42,
    "db": 43,
    "fl": 73,
    "ob": 68,
    "cl": 71,
    "sax": 66,
    "bn": 70,
    "tpt": 56,
    "hn": 60,
    "tbn": 57,
    "tba": 58
}

# %% [markdown]
# 生成的文件夹名称：
#
# {name}@{i}: name是作品的名字，i表示第几个声部，如果是0表示合并的

# %%
for folder_name in os.listdir(dataset_folder):
    folder_path = os.path.join(dataset_folder, folder_name)
    if os.path.isdir(folder_path):  # 对每一个重奏文件夹
        print(f"Processing folder: {folder_name}")
        # 找到所有音频和标注
        sepAudios = []
        mixAudio = None
        sepNotes = {}
        for file_name in os.listdir(folder_path):
            if file_name.endswith(".wav"):
                if file_name.startswith("AuMix"):
                    mixAudio = file_name
                if file_name.startswith("AuSep"):
                    sepAudios.append(file_name)
            elif file_name.endswith(".txt"):
                if file_name.startswith("Notes"):
                    sepNotes[file_name[6:-4]] = file_name

        if mixAudio is None:
            print(f"Mix audio not found in {folder_name}")
            continue

        midis = []
        for i, file in enumerate(sepAudios):
            raw_name= file[6:-4]
            print(f"\tProcessing {raw_name}")
            audio_absolute_path = os.path.join(folder_path, file)
            note_absolute_path = os.path.join(folder_path, sepNotes[raw_name])

            output_folder_path = os.path.join(output_folder, f"{folder_name}@{i+1}")
            if not os.path.exists(output_folder_path):
                os.makedirs(output_folder_path)

            # 音频用ffmpeg进行抗混叠降采样
            print("\t\tProcessing audio")
            output_audio_path = os.path.join(output_folder_path, f"{raw_name}.wav")
            try:
                subprocess.run(['ffmpeg', '-i', audio_absolute_path, '-ar', str(fs), output_audio_path], check=True)
            except subprocess.CalledProcessError as e:
                print(f"Error occurred while processing {audio_absolute_path}: {e}")

            # 生成midi
            print("\t\tProcessing midi")
            output_midi_path = os.path.join(output_folder_path, f"{raw_name}.mid")
            mid = annotation2midi(note_absolute_path, cols=["onset", "freq", "dur"], instrument=urmp_instruments[raw_name.split('_')[1]])
            mid.save(output_midi_path)
            midis.append(mid)

            # 根据midi生成numpy数组
            print("\t\tProcessing midiarray")
            arr = midi2numpy(output_midi_path, time_step)
            np.save(os.path.join(output_folder_path, f"{raw_name}.npy"), arr)
        
        # 最后处理混合版本
        raw_name= mixAudio[6:-4]
        print(f"\tProcessing {raw_name}")
        output_folder_path = os.path.join(output_folder, f"{folder_name}@0")
        if not os.path.exists(output_folder_path):
            os.makedirs(output_folder_path)

        print("\t\tProcessing audio")
        audio_absolute_path = os.path.join(folder_path, mixAudio)
        output_audio_path = os.path.join(output_folder_path, f"{raw_name}.wav")
        try:
            subprocess.run(['ffmpeg', '-i', audio_absolute_path, '-ar', str(fs), output_audio_path], check=True)
        except subprocess.CalledProcessError as e:
            print(f"Error occurred while processing {audio_absolute_path}: {e}")

        print("\t\tProcessing midi")
        output_midi_path = os.path.join(output_folder_path, f"{raw_name}.mid")
        midi_merge(midis).save(output_midi_path)

        print("\t\tProcessing midiarray")
        arr = midi2numpy(output_midi_path, time_step, track_separate=False) # 如果是basicamt这种音色无关就不分音轨了
        np.save(os.path.join(output_folder_path, f"{raw_name}.npy"), arr)
# Out:
# Processing folder: 01_Jupiter_vn_vc
# 	Processing 1_vn_01_Jupiter
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vc_01_Jupiter
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 01_Jupiter_vn_vc
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 02_Sonata_vn_vn
# 	Processing 1_vn_02_Sonata
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_02_Sonata
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 02_Sonata_vn_vn
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 03_Dance_fl_cl
# 	Processing 1_fl_03_Dance
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_cl_03_Dance
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 03_Dance_fl_cl
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 04_Allegro_fl_fl
# 	Processing 1_fl_04_Allegro
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_fl_04_Allegro
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 04_Allegro_fl_fl
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 05_Entertainer_tpt_tpt
# 	Processing 1_tpt_05_Entertainer
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_tpt_05_Entertainer
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 05_Entertainer_tpt_tpt
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 06_Entertainer_sax_sax
# 	Processing 1_sax_06_Entertainer
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_sax_06_Entertainer
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 06_Entertainer_sax_sax
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 07_GString_tpt_tbn
# 	Processing 1_tpt_07_GString
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_tbn_07_GString
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 07_GString_tpt_tbn
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 08_Spring_fl_vn
# 	Processing 1_fl_08_Spring
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_08_Spring
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 08_Spring_fl_vn
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 09_Jesus_tpt_vn
# 	Processing 1_tpt_09_Jesus
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_09_Jesus
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 09_Jesus_tpt_vn
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 10_March_tpt_sax
# 	Processing 1_tpt_10_March
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_sax_10_March
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 10_March_tpt_sax
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 11_Maria_ob_vc
# 	Processing 1_ob_11_Maria
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vc_11_Maria
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 11_Maria_ob_vc
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 12_Spring_vn_vn_vc
# 	Processing 1_vn_12_Spring
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_12_Spring
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_vc_12_Spring
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 12_Spring_vn_vn_vc
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 13_Hark_vn_vn_va
# 	Processing 1_vn_13_Hark
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_13_Hark
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_va_13_Hark
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 13_Hark_vn_vn_va
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 14_Waltz_fl_fl_cl
# 	Processing 1_fl_14_Waltz
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_fl_14_Waltz
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_cl_14_Waltz
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 14_Waltz_fl_fl_cl
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 15_Surprise_tpt_tpt_tbn
# 	Processing 1_tpt_15_Surprise
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_tpt_15_Surprise
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_tpt_15_Surprise
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 15_Surprise_tpt_tpt_tbn
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 16_Surprise_tpt_tpt_sax
# 	Processing 1_tpt_16_Surprise
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_tpt_16_Surprise
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_sax_16_Surprise
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 16_Surprise_tpt_tpt_sax
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 17_Nocturne_vn_fl_cl
# 	Processing 1_vn_17_Nocturne
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_fl_17_Nocturne
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_cl_17_Nocturne
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 17_Nocturne_vn_fl_cl
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 18_Nocturne_vn_fl_tpt
# 	Processing 1_vn_18_Nocturne
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_fl_18_Nocturne
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_tpt_18_Nocturne
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 18_Nocturne_vn_fl_tpt
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 19_Pavane_cl_vn_vc
# 	Processing 1_cl_19_Pavane
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_19_Pavane
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_vc_19_Pavane
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 19_Pavane_cl_vn_vc
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 20_Pavane_tpt_vn_vc
# 	Processing 1_tpt_20_Pavane
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_20_Pavane
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_vc_20_Pavane
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 20_Pavane_tpt_vn_vc
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 21_Rejouissance_cl_tbn_tba
# 	Processing 1_cl_21_Rejouissance
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_tbn_21_Rejouissance
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_tba_21_Rejouissance
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 21_Rejouissance_cl_tbn_tba
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 22_Rejouissance_sax_tbn_tba
# 	Processing 1_sax_22_Rejouissance
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_tbn_22_Rejouissance
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_tba_22_Rejouissance
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 22_Rejouissance_sax_tbn_tba
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 23_Rejouissance_cl_sax_tba
# 	Processing 1_cl_23_Rejouissance
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_sax_23_Rejouissance
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_tba_23_Rejouissance
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 23_Rejouissance_cl_sax_tba
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 24_Pirates_vn_vn_va_vc
# 	Processing 1_vn_24_Pirates
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_24_Pirates
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_va_24_Pirates
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_vc_24_Pirates
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 24_Pirates_vn_vn_va_vc
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 25_Pirates_vn_vn_va_sax
# 	Processing 1_vn_25_Pirates
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_25_Pirates
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_va_25_Pirates
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_sax_25_Pirates
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 25_Pirates_vn_vn_va_sax
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 26_King_vn_vn_va_vc
# 	Processing 1_vn_26_King
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_26_King
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_va_26_King
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_vc_26_King
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 26_King_vn_vn_va_vc
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 27_King_vn_vn_va_sax
# 	Processing 1_vn_27_King
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_27_King
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_va_27_King
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_sax_27_King
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 27_King_vn_vn_va_sax
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 28_Fugue_fl_ob_cl_bn
# 	Processing 1_fl_28_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_ob_28_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_cl_28_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_bn_28_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 28_Fugue_fl_ob_cl_bn
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 29_Fugue_fl_fl_ob_cl
# 	Processing 1_fl_29_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_fl_29_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_ob_29_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_cl_29_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 29_Fugue_fl_fl_ob_cl
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 30_Fugue_fl_fl_ob_sax
# 	Processing 1_fl_30_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_fl_30_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_ob_30_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_sax_30_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 30_Fugue_fl_fl_ob_sax
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 31_Slavonic_tpt_tpt_hn_tbn
# 	Processing 1_tpt_31_Slavonic
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_tpt_31_Slavonic
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_hn_31_Slavonic
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_tbn_31_Slavonic
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 31_Slavonic_tpt_tpt_hn_tbn
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 32_Fugue_vn_vn_va_vc
# 	Processing 1_vn_32_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_32_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_va_32_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_vc_32_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 32_Fugue_vn_vn_va_vc
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 33_Elise_tpt_tpt_hn_tbn
# 	Processing 1_tpt_33_Elise
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_tpt_33_Elise
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_hn_33_Elise
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_tbn_33_Elise
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 33_Elise_tpt_tpt_hn_tbn
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 34_Fugue_tpt_tpt_hn_tbn
# 	Processing 1_tpt_34_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_tpt_34_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_hn_34_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_tbn_34_Fugue
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 34_Fugue_tpt_tpt_hn_tbn
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 35_Rondeau_vn_vn_va_db
# 	Processing 1_vn_35_Rondeau
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_35_Rondeau
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_va_35_Rondeau
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_db_35_Rondeau
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 35_Rondeau_vn_vn_va_db
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 36_Rondeau_vn_vn_va_vc
# 	Processing 1_vn_36_Rondeau
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_36_Rondeau
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_va_36_Rondeau
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_vc_36_Rondeau
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 36_Rondeau_vn_vn_va_vc
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 37_Rondeau_fl_vn_va_cl
# 	Processing 1_fl_37_Rondeau
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_37_Rondeau
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_va_37_Rondeau
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_cl_37_Rondeau
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 37_Rondeau_fl_vn_va_cl
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 38_Jerusalem_vn_vn_va_vc_db
# 	Processing 1_vn_38_Jerusalem
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_38_Jerusalem
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_va_38_Jerusalem
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_vc_38_Jerusalem
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 5_db_38_Jerusalem
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 38_Jerusalem_vn_vn_va_vc_db
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 39_Jerusalem_vn_vn_va_sax_db
# 	Processing 1_vn_39_Jerusalem
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_39_Jerusalem
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_va_39_Jerusalem
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_sax_39_Jerusalem
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 5_db_39_Jerusalem
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 39_Jerusalem_vn_vn_va_sax_db
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 40_Miserere_fl_fl_ob_cl_bn
# 	Processing 1_fl_40_Miserere
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_fl_40_Miserere
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_ob_40_Miserere
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_cl_40_Miserere
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 5_bn_40_Miserere
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 40_Miserere_fl_fl_ob_cl_bn
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 41_Miserere_fl_fl_ob_sax_bn
# 	Processing 1_fl_41_Miserere
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_fl_41_Miserere
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_ob_41_Miserere
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_sax_41_Miserere
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 5_bn_41_Miserere
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 41_Miserere_fl_fl_ob_sax_bn
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 42_Arioso_tpt_tpt_hn_tbn_tba
# 	Processing 1_tpt_42_Arioso
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_tpt_42_Arioso
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_hn_42_Arioso
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_tbn_42_Arioso
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 5_tba_42_Arioso
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 42_Arioso_tpt_tpt_hn_tbn_tba
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 43_Chorale_tpt_tpt_hn_tbn_tba
# 	Processing 1_tpt_43_Chorale
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_tpt_43_Chorale
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_hn_43_Chorale
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_tbn_43_Chorale
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 5_tba_43_Chorale
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 43_Chorale_tpt_tpt_hn_tbn_tba
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: 44_K515_vn_vn_va_va_vc
# 	Processing 1_vn_44_K515
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 2_vn_44_K515
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 3_va_44_K515
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 4_va_44_K515
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 5_vc_44_K515
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# 	Processing 44_K515_vn_vn_va_va_vc
# 		Processing audio
# 		Processing midi
# 		Processing midiarray
# Processing folder: Supplementary_Files
# Mix audio not found in Supplementary_Files
